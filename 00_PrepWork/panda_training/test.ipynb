# %%
a = 23
print(a)
# Out:
# 23

# %%
b = 12
print(a+b)
# Out:
# 35

# %%
ma_valeur = 70
une_autre = 37
total = ma_valeur + une_autre
print(f"le total est de {total} €")
# Out:
# le total est de 107 €

# %%
valeur1, valeur2 = input("entrz la valeur1"), input("entrez la valeur2")
total = int(valeur1) + int(valeur2)
print(f"le total est de {total} €")
# Out:
# le total est de 90 €

# %%
["pair" if i % 2 == 0 else "impair" for i in range(20)]
# Out:
# ['pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair',
#  'pair',
#  'impair']

# %%
# !pwd
# Out:
# /Users/thierrylegros/00-JEDHA/Fullstack-AI/PrepWork

# %%
print([i*i for i in range(1,65)])
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100, 121, 144, 169, 196, 225, 256, 289, 324, 361, 400, 441, 484, 529, 576, 625, 676, 729, 784, 841, 900, 961, 1024, 1089, 1156, 1225, 1296, 1369, 1444, 1521, 1600, 1681, 1764, 1849, 1936, 2025, 2116, 2209, 2304, 2401, 2500, 2601, 2704, 2809, 2916, 3025, 3136, 3249, 3364, 3481, 3600, 3721, 3844, 3969, 4096]

# %%
import pandas as pd

df_data = pd.read_csv("/Users/thierrylegros/00-JEDHA/Fullstack-AI/PrepWork" + "/netflix_content_intelligence_combined.csv")

# %%
df_data.head(10)
# Out:
#         content_id  title     type  release_year  release_decade  \
# 0  nf_2879cda65363     3%  TV Show          2020            2020
# 1  nf_73818ff7bd91   7:19    Movie          2016            2010
# 2  nf_821496e58bca  23:59    Movie          2011            2010
# 3  nf_be2013d8c4ac      9    Movie          2009            2000
# 4  nf_f4e65f8e18a8     21    Movie          2008            2000
# 5  nf_18f0ffc9ca6e     46  TV Show          2016            2010
# 6  nf_6f5d5d8a5929    122    Movie          2019            2010
# 7  nf_db09b8438bb4    187    Movie          1997            1990
# 8  nf_8669252fff78    706    Movie          2019            2010
# 9  nf_42bc58992dd0   1920    Movie          2008            2000
#
#   release_year_group  content_age         date_added rating   duration  ...  \
# 0          2020-2022            6    August 14, 2020  TV-MA  4 Seasons  ...
# 1          2016-2019           10  December 23, 2016  TV-MA     93 min  ...
# ...

# %%
df_data_clean = df_data.iloc[:,1:]  
df_data_clean.head()
# Out:
#    title     type  release_year  release_decade release_year_group  \
# 0     3%  TV Show          2020            2020          2020-2022
# 1   7:19    Movie          2016            2010          2016-2019
# 2  23:59    Movie          2011            2010          2010-2015
# 3      9    Movie          2009            2000              2000s
# 4     21    Movie          2008            2000              2000s
#
#    content_age         date_added rating   duration  runtime_minutes  ...  \
# 0            6    August 14, 2020  TV-MA  4 Seasons             90.0  ...
# 1           10  December 23, 2016  TV-MA     93 min             94.0  ...
# 2           15  December 20, 2018      R     78 min             78.0  ...
# 3           17  November 16, 2017  PG-13     80 min             79.0  ...
# 4           18    January 1, 2020  PG-13    123 min            123.0  ...
#
#   primary_country country_count is_original is_recent_release has_rating  \
# ...

# %%
mask = df_data_clean["countries"] == "France"
df_data_clean[mask]
# Out:
#                            title     type  release_year  release_decade  \
# 49                10 jours en or    Movie          2012            2010
# 77              2 Alone in Paris    Movie          2008            2000
# 203                A Mighty Team    Movie          2016            2010
# 248        A Very Secret Service  TV Show          2018            2010
# 303                     Ad Vitam  TV Show          2018            2010
# ...                          ...      ...           ...             ...
# 7497                  We Are One    Movie          2020            2020
# 7516           Wedding Unplanned    Movie          2017            2010
# 7535                  West Coast    Movie          2016            2010
# 7604  Who Killed Little Gregory?  TV Show          2019            2010
# 7765                Zig & Sharko  TV Show          2016            2010
#
#      release_year_group  content_age         date_added rating   duration  \
# ...
